# %%
import matplotlib
matplotlib.use('nbagg')
import pandas as pd, numpy as np, matplotlib.pyplot as plt
import os

# %%
pwd
# Out:
# '/home/luke/Dropbox/software/mesa/results/writeup_plots'

# %%
table_dir = '../grid_production_0/tables/'
table_paths =  [table_dir+p for p in np.array(os.listdir('../grid_production_0/tables/'))]
bold_Z = 0.015
bold_Z_paths = np.sort(np.array([p for p in table_paths if str(bold_Z) in p]))
other_paths = np.sort(np.array([p for p in table_paths if str(bold_Z) not in p]))

bold_Z_tabs, other_tabs = {}, {}
for path in bold_Z_paths:
    bold_Z_tabs[path] = pd.read_csv(path, index_col='age')
for path in other_paths:
    other_tabs[path] = pd.read_csv(path, index_col='age')

# %%
np.sort(list(bold_Z_tabs.keys()))
# Out:
# array(['../grid_production_0/tables/M0.4_Z0.015.csv',
#        '../grid_production_0/tables/M0.5_Z0.015.csv',
#        '../grid_production_0/tables/M0.6_Z0.015.csv',
#        '../grid_production_0/tables/M0.7_Z0.015.csv',
#        '../grid_production_0/tables/M0.8_Z0.015.csv',
#        '../grid_production_0/tables/M0.9_Z0.015.csv',
#        '../grid_production_0/tables/M1.0_Z0.015.csv',
#        '../grid_production_0/tables/M1.1_Z0.015.csv',
#        '../grid_production_0/tables/M1.2_Z0.015.csv'],
#       dtype='<U43')

# %%
bold_Z_tabs[list(bold_Z_tabs.keys())[0]].head()
# Out:
#             R_star    L_star    M_star  R_tachocline  M_ini    M_conv  M_rad  \
# age
# 505314.6  3.326127  4.468923  1.199999           0.0    1.2  1.199999    0.0
# 541560.5  3.239412  4.245011  1.199999           0.0    1.2  1.199999    0.0
# 580539.0  3.155383  4.031079  1.199999           0.0    1.2  1.199999    0.0
# 622830.0  3.073270  3.827695  1.199999           0.0    1.2  1.199999    0.0
# 668446.5  2.993501  3.632515  1.199999           0.0    1.2  1.199999    0.0
#
#             I_conv  I_rad
# age
# 505314.6  2.637444    0.0
# 541560.5  2.503700    0.0
# 580539.0  2.377334    0.0
# 622830.0  2.256928    0.0
# 668446.5  2.142877    0.0

# %%
bold_Z_tabs['../grid_production_0/tables/M0.4_Z0.015.csv'].sort_index().head()
# Out:
#             R_star    L_star  M_star  R_tachocline  M_ini  M_conv  M_rad  \
# age
# 507197.3  2.376052  0.840243     0.4           0.0    0.4     0.4    0.0
# 537728.7  2.313886  0.792495     0.4           0.0    0.4     0.4    0.0
# 570532.5  2.253780  0.747903     0.4           0.0    0.4     0.4    0.0
# 606137.7  2.195492  0.706229     0.4           0.0    0.4     0.4    0.0
# 644907.4  2.138685  0.666949     0.4           0.0    0.4     0.4    0.0
#
#             I_conv  I_rad
# age
# 507197.3  0.437087    0.0
# 537728.7  0.415252    0.0
# 570532.5  0.394640    0.0
# 606137.7  0.375122    0.0
# 644907.4  0.356546    0.0

# %%
f, axs = plt.subplots(3, 2, sharex='col', figsize=(7,9.5))

for bk in list(bold_Z_tabs.keys()):
    this_table = bold_Z_tabs[bk]
    this_table = this_table.sort_index()
    this_table['I_tot'] = this_table['I_rad'] + this_table['I_conv']
    y_order = ['R_star', 'L_star', 'R_tachocline', 'I_conv', 'I_rad', 'I_tot']
    for i, ax in enumerate(axs.flatten()):
        this_y = y_order[i]
        ax.plot(np.log10(this_table.index.values), this_table[this_y], c='k')
        ax.set_ylabel(this_y)
        if i == 2 or i == 5:
            ax.set_xlabel('log10(age)')
f.tight_layout()        
f.show()
# Out:
# <img src="data:image/png;base64,...">
